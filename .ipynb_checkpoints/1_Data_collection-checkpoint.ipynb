# %% [markdown]
# # 1. Data collection - Pole Emploi API

# %% [markdown]
# ### Imports

# %%
import requests as r
import pandas as pd
import numpy as np
import json
import re
import time
import os
from datetime import datetime, timedelta
from tqdm.auto import tqdm
from collections import Counter

# %% [markdown]
# ### Load domain data
# Get list of domains of French masters to query PE API.

# %%
domains = pd.read_csv('./master_domains.tsv', sep='\t')
domains = domains['DOMAIN'].tolist()
print(len(domains))
domains[:3]
# Out:
# 73
# ['achats', 'logistique', 'qualité']

# %% [markdown]
# ### Pull data from PE API
# Run multiple queries based on each master domain to get related job postings.

# %%
def gen_access_token():
    url = 'https://entreprise.pole-emploi.fr/connexion/oauth2/access_token'
    url += '?realm=%2Fpartenaire'
    data = {
        'grant_type':    'client_credentials',
        'client_id':     'PAR_jobsearchapp_5a63edbe429e5210801dc8f115285a94b5909fe24ba9b5cfd956c2ed7b40824a',
        'client_secret': 'bd900cc2accfba406876700e13300d26b23e27485902b32de55d04e4a10c727a',
        'scope':         'api_offresdemploiv2 o2dsoffre',
    }
    res = r.post(url, data=data)
    try:
        return res.json()['access_token']
    except:
        print(res.__dict__)
        raise res.json()

def search_jobs(min_date, max_date, keywords=None):
    token = gen_access_token()
    url = "https://api.emploi-store.fr"
    url += "/partenaire/offresdemploi/v2/offres/search"
    headers = {"Authorization": f"Bearer {token}"}
    data = {
        'typeContrat': 'CDI',
        'sort': '0',
        'minCreationDate': min_date,
        'maxCreationDate': max_date,
    }
    if keywords:
        data['motsCles'] = keywords
    res = r.get(url, headers=headers, params=data)
    if res.status_code not in [200, 206]:
        print(f'Error: {res.status_code}')
        return None
    else:
        return res.json()

def get_job_by_id(job_id):
    token = gen_access_token()
    url = "https://api.emploi-store.fr"
    url += f"/partenaire/offresdemploi/v2/offres/{job_id}"
    headers = {"Authorization": f"Bearer {token}"}
    res = r.get(url, headers=headers)
    if res.status_code != 200:
        print(f'Error: {res.status_code}')
        return None
    else:
        try:
            return res.json()
        except:
            print(res.__dict__)
            raise res
    
def search_student_street_jobs(n_results):
    results = []
    stored_job_ids = []
    last_f_name = None
    max_date = (datetime.now() - timedelta(days=1)).replace(microsecond=0).isoformat() + 'Z'
    min_date = (datetime.now() - timedelta(days=31)).replace(microsecond=0).isoformat() + 'Z'
    min_date = '2022-09-15T07:39:28Z'
    max_date = '2022-10-15T07:39:28Z'
    
    # Loop over jobs
    while len(results) < n_results:
        print(min_date, max_date)
        try:
            jobs = search_jobs(min_date=min_date, max_date=max_date)
            if jobs:
                jobs = jobs['resultats']
                print(f'Jobs: {len(jobs)}')
                for job in tqdm(jobs):
                    time.sleep(1)
                    if job['id'] not in stored_job_ids:
                        j = get_job_by_id(job['id'])
                        if j:
                            results.append(j)
                        stored_job_ids.append(job['id'])
        except Exception as e:
            print(e)
            time.sleep(3600)
                    
        # Save batch
        print(f'Total stored results: {len(results)}')
        f_name = f'./pole_emploi/PE_jobs_{datetime.now().strftime("%Y-%m-%dT%H-%M-%S")}_{len(results)}.json'
        with open(f_name, 'w', encoding='utf-8') as f:
            json.dump(results, f, ensure_ascii=False, indent=4)
        if last_f_name:
            os.remove(last_f_name)
        last_f_name = f_name
        
        # Update datetimes 2022-10-10T23:54:27.000Z
        max_date = jobs[-1]['dateCreation'][:-5] + 'Z'
        min_date = (datetime.strptime(max_date, '%Y-%m-%dT%H:%M:%SZ') - timedelta(days=31)) \
                   .replace(microsecond=0).isoformat() + 'Z'
        
        # Wait 1h if no jobs
        time.sleep(1)
        if not jobs:
            time.sleep(3600)
        
    return results

# data = search_student_street_jobs(n_results=50_000)

domain_jobs = {}

for domain in tqdm(domains[:]):
    print(domain)
    
    combs = []
    templates = ['{} ET bac+5', '{} ET bac+4', '{} ET bac+3']
    combs += [t.format(domain) for t in templates]
    if ', ' in domain:
        sub_combs = [[t.format(x) for x in domain.split(', ')] for t in templates]
        sub_combs = [a for b in sub_combs for a in b]
        combs += sub_combs
    combs += [domain]
    if ', ' in domain:
        combs += domain.split(', ')
    
    print(combs)
    jobs = []
    while len(jobs) < 5 and combs:
        try:
            comb = combs.pop(0)
            print(f'   -> {comb}')
            data = search_jobs(min_date='2020-10-30T00:00:00Z',
                               max_date='2022-10-30T00:00:00Z',
                               keywords=comb)
            if data:
                results = [x['appellationlibelle'] for x in data['resultats']]
                results = Counter(results)
                results = results.most_common(5)
                results = [x[0] for x in results if x[-1] > 1]
                jobs.extend(results)
                jobs = list(set(jobs))

            time.sleep(1)
        except:
            print('Error')
            combs = [comb] + combs
            time.sleep(2)
            
    domain_jobs[domain] = jobs
    
with open('./domain_jobs_top5.json', 'w', encoding='utf-8') as f:
    json.dump(domain_jobs, f, ensure_ascii=False, indent=4)
# Out:
#   0%|          | 0/73 [00:00<?, ?it/s]
# achats
# ['achats ET bac+5', 'achats ET bac+4', 'achats ET bac+3', 'achats']
#    -> achats ET bac+5
#    -> achats ET bac+4
#    -> achats ET bac+3
#    -> achats
# logistique
# ['logistique ET bac+5', 'logistique ET bac+4', 'logistique ET bac+3', 'logistique']
#    -> logistique ET bac+5
# qualité
# ['qualité ET bac+5', 'qualité ET bac+4', 'qualité ET bac+3', 'qualité']
#    -> qualité ET bac+5
# assurance, actuariat
# ['assurance, actuariat ET bac+5', 'assurance, actuariat ET bac+4', 'assurance, actuariat ET bac+3', 'assurance ET bac+5', 'actuariat ET bac+5', 'assurance ET bac+4', 'actuariat ET bac+4', 'assurance ET bac+3', 'actuariat ET bac+3', 'assurance, actuariat', 'assurance', 'actuariat']
#    -> assurance, actuariat ET bac+5
# Error: 204
#    -> assurance, actuariat ET bac+4
# Error: 204
#    -> assurance, actuariat ET bac+3
# Error: 204
#    -> assurance ET bac+5
#    -> actuariat ET bac+5
# Error: 204
#    -> assurance ET bac+4
# audit, conseil
# ['audit, conseil ET bac+5', 'audit, conseil ET bac+4', 'audit, conseil ET bac+3', 'audit ET bac+5', 'conseil ET bac+5', 'audit ET bac+4', 'conseil ET bac+4', 'audit ET bac+3', 'conseil ET bac+3', 'audit, conseil', 'audit', 'conseil']
#    -> audit, conseil ET bac+5
#    -> audit, conseil ET bac+4
# Error: 204
#    -> audit, conseil ET bac+3
# Error: 204
#    -> audit ET bac+5
# audit interne, contrôle de gestion
# ['audit interne, contrôle de gestion ET bac+5', 'audit interne, contrôle de gestion ET bac+4', 'audit interne, contrôle de gestion ET bac+3', 'audit interne ET bac+5', 'contrôle de gestion ET bac+5', 'audit interne ET bac+4', 'contrôle de gestion ET bac+4', 'audit interne ET bac+3', 'contrôle de gestion ET bac+3', 'audit interne, contrôle de gestion', 'audit interne', 'contrôle de gestion']
#    -> audit interne, contrôle de gestion ET bac+5
#    -> audit interne, contrôle de gestion ET bac+4
# Error: 204
#    -> audit interne, contrôle de gestion ET bac+3
# Error: 204
#    -> audit interne ET bac+5
#    -> contrôle de gestion ET bac+5
#    -> audit interne ET bac+4
#    -> contrôle de gestion ET bac+4
#    -> audit interne ET bac+3
#    -> contrôle de gestion ET bac+3
#    -> audit interne, contrôle de gestion
# banque, finance
# ['banque, finance ET bac+5', 'banque, finance ET bac+4', 'banque, finance ET bac+3', 'banque ET bac+5', 'finance ET bac+5', 'banque ET bac+4', 'finance ET bac+4', 'banque ET bac+3', 'finance ET bac+3', 'banque, finance', 'banque', 'finance']
#    -> banque, finance ET bac+5
#    -> banque, finance ET bac+4
#    -> banque, finance ET bac+3
#    -> banque ET bac+5
#    -> finance ET bac+5
#    -> banque ET bac+4
# banque, conseil bancaire
# ['banque, conseil bancaire ET bac+5', 'banque, conseil bancaire ET bac+4', 'banque, conseil bancaire ET bac+3', 'banque ET bac+5', 'conseil bancaire ET bac+5', 'banque ET bac+4', 'conseil bancaire ET bac+4', 'banque ET bac+3', 'conseil bancaire ET bac+3', 'banque, conseil bancaire', 'banque', 'conseil bancaire']
#    -> banque, conseil bancaire ET bac+5
# Error: 204
#    -> banque, conseil bancaire ET bac+4
# Error: 204
#    -> banque, conseil bancaire ET bac+3
# Error: 204
#    -> banque ET bac+5
#    -> conseil bancaire ET bac+5
# Error: 204
#    -> banque ET bac+4
# expertise comptable, comptabilité, contrôle, audit
# ['expertise comptable, comptabilité, contrôle, audit ET bac+5', 'expertise comptable, comptabilité, contrôle, audit ET bac+4', 'expertise comptable, comptabilité, contrôle, audit ET bac+3', 'expertise comptable ET bac+5', 'comptabilité ET bac+5', 'contrôle ET bac+5', 'audit ET bac+5', 'expertise comptable ET bac+4', 'comptabilité ET bac+4', 'contrôle ET bac+4', 'audit ET bac+4', 'expertise comptable ET bac+3', 'comptabilité ET bac+3', 'contrôle ET bac+3', 'audit ET bac+3', 'expertise comptable, comptabilité, contrôle, audit', 'expertise comptable', 'comptabilité', 'contrôle', 'audit']
#    -> expertise comptable, comptabilité, contrôle, audit ET bac+5
#    -> expertise comptable, comptabilité, contrôle, audit ET bac+4
#    -> expertise comptable, comptabilité, contrôle, audit ET bac+3
#    -> expertise comptable ET bac+5
#    -> comptabilité ET bac+5
# finance de marché, gestion de portefeuille
# ['finance de marché, gestion de portefeuille ET bac+5', 'finance de marché, gestion de portefeuille ET bac+4', 'finance de marché, gestion de portefeuille ET bac+3', 'finance de marché ET bac+5', 'gestion de portefeuille ET bac+5', 'finance de marché ET bac+4', 'gestion de portefeuille ET bac+4', 'finance de marché ET bac+3', 'gestion de portefeuille ET bac+3', 'finance de marché, gestion de portefeuille', 'finance de marché', 'gestion de portefeuille']
#    -> finance de marché, gestion de portefeuille ET bac+5
# Error: 204
#    -> finance de marché, gestion de portefeuille ET bac+4
# Error: 204
#    -> finance de marché, gestion de portefeuille ET bac+3
# Error: 204
#    -> finance de marché ET bac+5
#    -> gestion de portefeuille ET bac+5
#    -> finance de marché ET bac+4
#    -> gestion de portefeuille ET bac+4
#    -> finance de marché ET bac+3
#    -> gestion de portefeuille ET bac+3
#    -> finance de marché, gestion de portefeuille
#    -> finance de marché
# gestion de patrimoine
# ['gestion de patrimoine ET bac+5', 'gestion de patrimoine ET bac+4', 'gestion de patrimoine ET bac+3', 'gestion de patrimoine']
#    -> gestion de patrimoine ET bac+5
#    -> gestion de patrimoine ET bac+4
#    -> gestion de patrimoine ET bac+3
#    -> gestion de patrimoine
# compliance, conformité
# ['compliance, conformité ET bac+5', 'compliance, conformité ET bac+4', 'compliance, conformité ET bac+3', 'compliance ET bac+5', 'conformité ET bac+5', 'compliance ET bac+4', 'conformité ET bac+4', 'compliance ET bac+3', 'conformité ET bac+3', 'compliance, conformité', 'compliance', 'conformité']
#    -> compliance, conformité ET bac+5
# Error: 204
#    -> compliance, conformité ET bac+4
# Error: 204
#    -> compliance, conformité ET bac+3
# Error: 204
#    -> compliance ET bac+5
# Error: 204
#    -> conformité ET bac+5
# Error: 204
#    -> compliance ET bac+4
# Error: 204
#    -> conformité ET bac+4
#    -> compliance ET bac+3
# Error: 204
#    -> conformité ET bac+3
#    -> compliance, conformité
#    -> compliance
#    -> conformité
# immobilier, droit, management
# ['immobilier, droit, management ET bac+5', 'immobilier, droit, management ET bac+4', 'immobilier, droit, management ET bac+3', 'immobilier ET bac+5', 'droit ET bac+5', 'management ET bac+5', 'immobilier ET bac+4', 'droit ET bac+4', 'management ET bac+4', 'immobilier ET bac+3', 'droit ET bac+3', 'management ET bac+3', 'immobilier, droit, management', 'immobilier', 'droit', 'management']
#    -> immobilier, droit, management ET bac+5
# Error: 204
#    -> immobilier, droit, management ET bac+4
# Error: 204
#    -> immobilier, droit, management ET bac+3
# Error: 204
#    -> immobilier ET bac+5
# ingénierie financière, finance d'entreprise
# ["ingénierie financière, finance d'entreprise ET bac+5", "ingénierie financière, finance d'entreprise ET bac+4", "ingénierie financière, finance d'entreprise ET bac+3", 'ingénierie financière ET bac+5', "finance d'entreprise ET bac+5", 'ingénierie financière ET bac+4', "finance d'entreprise ET bac+4", 'ingénierie financière ET bac+3', "finance d'entreprise ET bac+3", "ingénierie financière, finance d'entreprise", 'ingénierie financière', "finance d'entreprise"]
#    -> ingénierie financière, finance d'entreprise ET bac+5
#    -> ingénierie financière, finance d'entreprise ET bac+4
# Error: 204
#    -> ingénierie financière, finance d'entreprise ET bac+3
# Error: 204
#    -> ingénierie financière ET bac+5
#    -> finance d'entreprise ET bac+5
#    -> ingénierie financière ET bac+4
# Error: 204
#    -> finance d'entreprise ET bac+4
#    -> ingénierie financière ET bac+3
# Error: 204
#    -> finance d'entreprise ET bac+3
#    -> ingénierie financière, finance d'entreprise
#    -> ingénierie financière
# communication
# ['communication ET bac+5', 'communication ET bac+4', 'communication ET bac+3', 'communication']
#    -> communication ET bac+5
# communication digitale
# ['communication digitale ET bac+5', 'communication digitale ET bac+4', 'communication digitale ET bac+3', 'communication digitale']
#    -> communication digitale ET bac+5
#    -> communication digitale ET bac+4
#    -> communication digitale ET bac+3
#    -> communication digitale
# communication événementielle
# ['communication événementielle ET bac+5', 'communication événementielle ET bac+4', 'communication événementielle ET bac+3', 'communication événementielle']
#    -> communication événementielle ET bac+5
#    -> communication événementielle ET bac+4
#    -> communication événementielle ET bac+3
#    -> communication événementielle
# communication publique
# ['communication publique ET bac+5', 'communication publique ET bac+4', 'communication publique ET bac+3', 'communication publique']
#    -> communication publique ET bac+5
#    -> communication publique ET bac+4
# direction artistique, graphisme, design
# ['direction artistique, graphisme, design ET bac+5', 'direction artistique, graphisme, design ET bac+4', 'direction artistique, graphisme, design ET bac+3', 'direction artistique ET bac+5', 'graphisme ET bac+5', 'design ET bac+5', 'direction artistique ET bac+4', 'graphisme ET bac+4', 'design ET bac+4', 'direction artistique ET bac+3', 'graphisme ET bac+3', 'design ET bac+3', 'direction artistique, graphisme, design', 'direction artistique', 'graphisme', 'design']
#    -> direction artistique, graphisme, design ET bac+5
# Error: 204
#    -> direction artistique, graphisme, design ET bac+4
# Error: 204
#    -> direction artistique, graphisme, design ET bac+3
# Error: 204
#    -> direction artistique ET bac+5
#    -> graphisme ET bac+5
#    -> design ET bac+5
#    -> direction artistique ET bac+4
# Error: 204
#    -> graphisme ET bac+4
# Error: 204
#    -> design ET bac+4
#    -> direction artistique ET bac+3
# Error: 204
#    -> graphisme ET bac+3
# Error: 204
#    -> design ET bac+3
#    -> direction artistique, graphisme, design
# Error: 204
#    -> direction artistique
#    -> graphisme
# médias, audiovisuel
# ['médias, audiovisuel ET bac+5', 'médias, audiovisuel ET bac+4', 'médias, audiovisuel ET bac+3', 'médias ET bac+5', 'audiovisuel ET bac+5', 'médias ET bac+4', 'audiovisuel ET bac+4', 'médias ET bac+3', 'audiovisuel ET bac+3', 'médias, audiovisuel', 'médias', 'audiovisuel']
#    -> médias, audiovisuel ET bac+5
# Error: 204
#    -> médias, audiovisuel ET bac+4
# Error: 204
#    -> médias, audiovisuel ET bac+3
# Error: 204
#    -> médias ET bac+5
#    -> audiovisuel ET bac+5
#    -> médias ET bac+4
#    -> audiovisuel ET bac+4
#    -> médias ET bac+3
#    -> audiovisuel ET bac+3
#    -> médias, audiovisuel
#    -> médias
# energies, energies renouvelables
# ['energies, energies renouvelables ET bac+5', 'energies, energies renouvelables ET bac+4', 'energies, energies renouvelables ET bac+3', 'energies ET bac+5', 'energies renouvelables ET bac+5', 'energies ET bac+4', 'energies renouvelables ET bac+4', 'energies ET bac+3', 'energies renouvelables ET bac+3', 'energies, energies renouvelables', 'energies', 'energies renouvelables']
#    -> energies, energies renouvelables ET bac+5
#    -> energies, energies renouvelables ET bac+4
# Error: 204
#    -> energies, energies renouvelables ET bac+3
# Error: 204
#    -> energies ET bac+5
#    -> energies renouvelables ET bac+5
#    -> energies ET bac+4
#    -> energies renouvelables ET bac+4
# Error: 204
#    -> energies ET bac+3
#    -> energies renouvelables ET bac+3
# Error: 204
#    -> energies, energies renouvelables
# environnement, développement durable
# ['environnement, développement durable ET bac+5', 'environnement, développement durable ET bac+4', 'environnement, développement durable ET bac+3', 'environnement ET bac+5', 'développement durable ET bac+5', 'environnement ET bac+4', 'développement durable ET bac+4', 'environnement ET bac+3', 'développement durable ET bac+3', 'environnement, développement durable', 'environnement', 'développement durable']
#    -> environnement, développement durable ET bac+5
#    -> environnement, développement durable ET bac+4
#    -> environnement, développement durable ET bac+3
#    -> environnement ET bac+5
# urbanisme
# ['urbanisme ET bac+5', 'urbanisme ET bac+4', 'urbanisme ET bac+3', 'urbanisme']
#    -> urbanisme ET bac+5
# mobilité, transports
# ['mobilité, transports ET bac+5', 'mobilité, transports ET bac+4', 'mobilité, transports ET bac+3', 'mobilité ET bac+5', 'transports ET bac+5', 'mobilité ET bac+4', 'transports ET bac+4', 'mobilité ET bac+3', 'transports ET bac+3', 'mobilité, transports', 'mobilité', 'transports']
#    -> mobilité, transports ET bac+5
# Error: 204
#    -> mobilité, transports ET bac+4
# Error: 204
#    -> mobilité, transports ET bac+3
# Error: 204
#    -> mobilité ET bac+5
# Error: 204
#    -> transports ET bac+5
#    -> mobilité ET bac+4
#    -> transports ET bac+4
# qualité, sécurité
# ['qualité, sécurité ET bac+5', 'qualité, sécurité ET bac+4', 'qualité, sécurité ET bac+3', 'qualité ET bac+5', 'sécurité ET bac+5', 'qualité ET bac+4', 'sécurité ET bac+4', 'qualité ET bac+3', 'sécurité ET bac+3', 'qualité, sécurité', 'qualité', 'sécurité']
#    -> qualité, sécurité ET bac+5
#    -> qualité, sécurité ET bac+4
# rse
# ['rse ET bac+5', 'rse ET bac+4', 'rse ET bac+3', 'rse']
#    -> rse ET bac+5
#    -> rse ET bac+4
#    -> rse ET bac+3
#    -> rse
# contentieux
# ['contentieux ET bac+5', 'contentieux ET bac+4', 'contentieux ET bac+3', 'contentieux']
#    -> contentieux ET bac+5
# Error: 204
#    -> contentieux ET bac+4
# Error: 204
#    -> contentieux ET bac+3
# Error: 204
#    -> contentieux
# droit des affaires
# ['droit des affaires ET bac+5', 'droit des affaires ET bac+4', 'droit des affaires ET bac+3', 'droit des affaires']
#    -> droit des affaires ET bac+5
#    -> droit des affaires ET bac+4
#    -> droit des affaires ET bac+3
#    -> droit des affaires
# droit du numérique, rgpd, données personnelles
# ['droit du numérique, rgpd, données personnelles ET bac+5', 'droit du numérique, rgpd, données personnelles ET bac+4', 'droit du numérique, rgpd, données personnelles ET bac+3', 'droit du numérique ET bac+5', 'rgpd ET bac+5', 'données personnelles ET bac+5', 'droit du numérique ET bac+4', 'rgpd ET bac+4', 'données personnelles ET bac+4', 'droit du numérique ET bac+3', 'rgpd ET bac+3', 'données personnelles ET bac+3', 'droit du numérique, rgpd, données personnelles', 'droit du numérique', 'rgpd', 'données personnelles']
#    -> droit du numérique, rgpd, données personnelles ET bac+5
# Error: 204
#    -> droit du numérique, rgpd, données personnelles ET bac+4
# Error: 204
#    -> droit du numérique, rgpd, données personnelles ET bac+3
# Error: 204
#    -> droit du numérique ET bac+5
#    -> rgpd ET bac+5
#    -> données personnelles ET bac+5
# Error: 204
#    -> droit du numérique ET bac+4
#    -> rgpd ET bac+4
#    -> données personnelles ET bac+4
#    -> droit du numérique ET bac+3
#    -> rgpd ET bac+3
#    -> données personnelles ET bac+3
#    -> droit du numérique, rgpd, données personnelles
# Error: 204
#    -> droit du numérique
#    -> rgpd
#    -> données personnelles
# droit de la concurrence, droit des affaires
# ['droit de la concurrence, droit des affaires ET bac+5', 'droit de la concurrence, droit des affaires ET bac+4', 'droit de la concurrence, droit des affaires ET bac+3', 'droit de la concurrence ET bac+5', 'droit des affaires ET bac+5', 'droit de la concurrence ET bac+4', 'droit des affaires ET bac+4', 'droit de la concurrence ET bac+3', 'droit des affaires ET bac+3', 'droit de la concurrence, droit des affaires', 'droit de la concurrence', 'droit des affaires']
#    -> droit de la concurrence, droit des affaires ET bac+5
# Error: 204
#    -> droit de la concurrence, droit des affaires ET bac+4
# Error: 204
#    -> droit de la concurrence, droit des affaires ET bac+3
# Error: 204
#    -> droit de la concurrence ET bac+5
# Error: 204
#    -> droit des affaires ET bac+5
#    -> droit de la concurrence ET bac+4
# Error: 204
#    -> droit des affaires ET bac+4
#    -> droit de la concurrence ET bac+3
# Error: 204
#    -> droit des affaires ET bac+3
#    -> droit de la concurrence, droit des affaires
# Error: 204
#    -> droit de la concurrence
#    -> droit des affaires
# droit international des affaires
# ['droit international des affaires ET bac+5', 'droit international des affaires ET bac+4', 'droit international des affaires ET bac+3', 'droit international des affaires']
#    -> droit international des affaires ET bac+5
# Error: 204
#    -> droit international des affaires ET bac+4
# Error: 204
#    -> droit international des affaires ET bac+3
# Error: 204
#    -> droit international des affaires
# droit social
# ['droit social ET bac+5', 'droit social ET bac+4', 'droit social ET bac+3', 'droit social']
#    -> droit social ET bac+5
# fiscalité, droit fiscal
# ['fiscalité, droit fiscal ET bac+5', 'fiscalité, droit fiscal ET bac+4', 'fiscalité, droit fiscal ET bac+3', 'fiscalité ET bac+5', 'droit fiscal ET bac+5', 'fiscalité ET bac+4', 'droit fiscal ET bac+4', 'fiscalité ET bac+3', 'droit fiscal ET bac+3', 'fiscalité, droit fiscal', 'fiscalité', 'droit fiscal']
#    -> fiscalité, droit fiscal ET bac+5
# Error: 204
#    -> fiscalité, droit fiscal ET bac+4
# Error: 204
#    -> fiscalité, droit fiscal ET bac+3
# Error: 204
#    -> fiscalité ET bac+5
# entrepreneuriat
# ['entrepreneuriat ET bac+5', 'entrepreneuriat ET bac+4', 'entrepreneuriat ET bac+3', 'entrepreneuriat']
#    -> entrepreneuriat ET bac+5
#    -> entrepreneuriat ET bac+4
#    -> entrepreneuriat ET bac+3
#    -> entrepreneuriat
# management de projets
# ['management de projets ET bac+5', 'management de projets ET bac+4', 'management de projets ET bac+3', 'management de projets']
#    -> management de projets ET bac+5
# gestion de la production industrielle
# ['gestion de la production industrielle ET bac+5', 'gestion de la production industrielle ET bac+4', 'gestion de la production industrielle ET bac+3', 'gestion de la production industrielle']
#    -> gestion de la production industrielle ET bac+5
#    -> gestion de la production industrielle ET bac+4
#    -> gestion de la production industrielle ET bac+3
#    -> gestion de la production industrielle
# innovation
# ['innovation ET bac+5', 'innovation ET bac+4', 'innovation ET bac+3', 'innovation']
#    -> innovation ET bac+5
#    -> innovation ET bac+4
# Error: 204
#    -> innovation ET bac+3
# Error: 204
#    -> innovation
# commerce international
# ['commerce international ET bac+5', 'commerce international ET bac+4', 'commerce international ET bac+3', 'commerce international']
#    -> commerce international ET bac+5
#    -> commerce international ET bac+4
# humanitaire
# ['humanitaire ET bac+5', 'humanitaire ET bac+4', 'humanitaire ET bac+3', 'humanitaire']
#    -> humanitaire ET bac+5
# Error: 204
#    -> humanitaire ET bac+4
# Error: 204
#    -> humanitaire ET bac+3
# Error: 204
#    -> humanitaire
# management international
# ['management international ET bac+5', 'management international ET bac+4', 'management international ET bac+3', 'management international']
#    -> management international ET bac+5
#    -> management international ET bac+4
#    -> management international ET bac+3
#    -> management international
# etablissements de santé
# ['etablissements de santé ET bac+5', 'etablissements de santé ET bac+4', 'etablissements de santé ET bac+3', 'etablissements de santé']
#    -> etablissements de santé ET bac+5
#    -> etablissements de santé ET bac+4
#    -> etablissements de santé ET bac+3
#    -> etablissements de santé
# gestion des ressources humaines
# ['gestion des ressources humaines ET bac+5', 'gestion des ressources humaines ET bac+4', 'gestion des ressources humaines ET bac+3', 'gestion des ressources humaines']
#    -> gestion des ressources humaines ET bac+5
# management public
# ['management public ET bac+5', 'management public ET bac+4', 'management public ET bac+3', 'management public']
#    -> management public ET bac+5
# management stratégique
# ['management stratégique ET bac+5', 'management stratégique ET bac+4', 'management stratégique ET bac+3', 'management stratégique']
#    -> management stratégique ET bac+5
# Error: 204
#    -> management stratégique ET bac+4
# Error: 204
#    -> management stratégique ET bac+3
# Error: 204
#    -> management stratégique
# marketing, relation client
# ['marketing, relation client ET bac+5', 'marketing, relation client ET bac+4', 'marketing, relation client ET bac+3', 'marketing ET bac+5', 'relation client ET bac+5', 'marketing ET bac+4', 'relation client ET bac+4', 'marketing ET bac+3', 'relation client ET bac+3', 'marketing, relation client', 'marketing', 'relation client']
#    -> marketing, relation client ET bac+5
#    -> marketing, relation client ET bac+4
#    -> marketing, relation client ET bac+3
#    -> marketing ET bac+5
# hôtellerie
# ['hôtellerie ET bac+5', 'hôtellerie ET bac+4', 'hôtellerie ET bac+3', 'hôtellerie']
#    -> hôtellerie ET bac+5
#    -> hôtellerie ET bac+4
#    -> hôtellerie ET bac+3
#    -> hôtellerie
# mode
# ['mode ET bac+5', 'mode ET bac+4', 'mode ET bac+3', 'mode']
#    -> mode ET bac+5
#    -> mode ET bac+4
#    -> mode ET bac+3
#    -> mode
# entreprises culturelles
# ['entreprises culturelles ET bac+5', 'entreprises culturelles ET bac+4', 'entreprises culturelles ET bac+3', 'entreprises culturelles']
#    -> entreprises culturelles ET bac+5
#    -> entreprises culturelles ET bac+4
#    -> entreprises culturelles ET bac+3
#    -> entreprises culturelles
# luxe
# ['luxe ET bac+5', 'luxe ET bac+4', 'luxe ET bac+3', 'luxe']
#    -> luxe ET bac+5
# Error: 204
#    -> luxe ET bac+4
# Error: 204
#    -> luxe ET bac+3
# Error: 204
#    -> luxe
# sport, e-sport
# ['sport, e-sport ET bac+5', 'sport, e-sport ET bac+4', 'sport, e-sport ET bac+3', 'sport ET bac+5', 'e-sport ET bac+5', 'sport ET bac+4', 'e-sport ET bac+4', 'sport ET bac+3', 'e-sport ET bac+3', 'sport, e-sport', 'sport', 'e-sport']
#    -> sport, e-sport ET bac+5
# Error: 204
#    -> sport, e-sport ET bac+4
# Error: 204
#    -> sport, e-sport ET bac+3
# Error: 204
#    -> sport ET bac+5
# Error: 204
#    -> e-sport ET bac+5
# Error: 204
#    -> sport ET bac+4
#    -> e-sport ET bac+4
# Error: 204
#    -> sport ET bac+3
#    -> e-sport ET bac+3
# Error: 204
#    -> sport, e-sport
#    -> sport
# tourisme
# ['tourisme ET bac+5', 'tourisme ET bac+4', 'tourisme ET bac+3', 'tourisme']
#    -> tourisme ET bac+5
#    -> tourisme ET bac+4
#    -> tourisme ET bac+3
#    -> tourisme
# management gastronomie
# ['management gastronomie ET bac+5', 'management gastronomie ET bac+4', 'management gastronomie ET bac+3', 'management gastronomie']
#    -> management gastronomie ET bac+5
# Error: 204
#    -> management gastronomie ET bac+4
# Error: 204
#    -> management gastronomie ET bac+3
# Error: 204
#    -> management gastronomie
# biotechnologie
# ['biotechnologie ET bac+5', 'biotechnologie ET bac+4', 'biotechnologie ET bac+3', 'biotechnologie']
#    -> biotechnologie ET bac+5
#    -> biotechnologie ET bac+4
#    -> biotechnologie ET bac+3
#    -> biotechnologie
# arts
# ['arts ET bac+5', 'arts ET bac+4', 'arts ET bac+3', 'arts']
#    -> arts ET bac+5
#    -> arts ET bac+4
#    -> arts ET bac+3
#    -> arts
# data analytics, analyse de données, big data
# ['data analytics, analyse de données, big data ET bac+5', 'data analytics, analyse de données, big data ET bac+4', 'data analytics, analyse de données, big data ET bac+3', 'data analytics ET bac+5', 'analyse de données ET bac+5', 'big data ET bac+5', 'data analytics ET bac+4', 'analyse de données ET bac+4', 'big data ET bac+4', 'data analytics ET bac+3', 'analyse de données ET bac+3', 'big data ET bac+3', 'data analytics, analyse de données, big data', 'data analytics', 'analyse de données', 'big data']
#    -> data analytics, analyse de données, big data ET bac+5
# Error: 204
#    -> data analytics, analyse de données, big data ET bac+4
# Error: 204
#    -> data analytics, analyse de données, big data ET bac+3
# Error: 204
#    -> data analytics ET bac+5
# Error: 204
#    -> analyse de données ET bac+5
#    -> big data ET bac+5
#    -> data analytics ET bac+4
# Error: 204
#    -> analyse de données ET bac+4
#    -> big data ET bac+4
# Error: 204
#    -> data analytics ET bac+3
# Error: 204
#    -> analyse de données ET bac+3
#    -> big data ET bac+3
# Error: 204
#    -> data analytics, analyse de données, big data
#    -> data analytics
#    -> analyse de données
# études marketing
# ['études marketing ET bac+5', 'études marketing ET bac+4', 'études marketing ET bac+3', 'études marketing']
#    -> études marketing ET bac+5
#    -> études marketing ET bac+4
# Error: 204
#    -> études marketing ET bac+3
# Error: 204
#    -> études marketing
# business development
# ['business development ET bac+5', 'business development ET bac+4', 'business development ET bac+3', 'business development']
#    -> business development ET bac+5
# Error: 204
#    -> business development ET bac+4
# Error: 204
#    -> business development ET bac+3
# Error: 204
#    -> business development
# data science, machine learning, big data
# ['data science, machine learning, big data ET bac+5', 'data science, machine learning, big data ET bac+4', 'data science, machine learning, big data ET bac+3', 'data science ET bac+5', 'machine learning ET bac+5', 'big data ET bac+5', 'data science ET bac+4', 'machine learning ET bac+4', 'big data ET bac+4', 'data science ET bac+3', 'machine learning ET bac+3', 'big data ET bac+3', 'data science, machine learning, big data', 'data science', 'machine learning', 'big data']
#    -> data science, machine learning, big data ET bac+5
# Error: 204
#    -> data science, machine learning, big data ET bac+4
# Error: 204
#    -> data science, machine learning, big data ET bac+3
# Error: 204
#    -> data science ET bac+5
# Error: 204
#    -> machine learning ET bac+5
#    -> big data ET bac+5
#    -> data science ET bac+4
# Error: 204
#    -> machine learning ET bac+4
# Error: 204
#    -> big data ET bac+4
# Error: 204
#    -> data science ET bac+3
# Error: 204
#    -> machine learning ET bac+3
# Error: 204
#    -> big data ET bac+3
# Error: 204
#    -> data science, machine learning, big data
# Error: 204
#    -> data science
#    -> machine learning
#    -> big data
# business intelligence, informatique décisionnelle
# ['business intelligence, informatique décisionnelle ET bac+5', 'business intelligence, informatique décisionnelle ET bac+4', 'business intelligence, informatique décisionnelle ET bac+3', 'business intelligence ET bac+5', 'informatique décisionnelle ET bac+5', 'business intelligence ET bac+4', 'informatique décisionnelle ET bac+4', 'business intelligence ET bac+3', 'informatique décisionnelle ET bac+3', 'business intelligence, informatique décisionnelle', 'business intelligence', 'informatique décisionnelle']
#    -> business intelligence, informatique décisionnelle ET bac+5
#    -> business intelligence, informatique décisionnelle ET bac+4
# Error: 204
#    -> business intelligence, informatique décisionnelle ET bac+3
# Error: 204
#    -> business intelligence ET bac+5
# Error: 204
#    -> informatique décisionnelle ET bac+5
#    -> business intelligence ET bac+4
#    -> informatique décisionnelle ET bac+4
#    -> business intelligence ET bac+3
#    -> informatique décisionnelle ET bac+3
#    -> business intelligence, informatique décisionnelle
#    -> business intelligence
#    -> informatique décisionnelle
# cybersécurité
# ['cybersécurité ET bac+5', 'cybersécurité ET bac+4', 'cybersécurité ET bac+3', 'cybersécurité']
#    -> cybersécurité ET bac+5
# Error: 204
#    -> cybersécurité ET bac+4
#    -> cybersécurité ET bac+3
#    -> cybersécurité
# protection des données
# ['protection des données ET bac+5', 'protection des données ET bac+4', 'protection des données ET bac+3', 'protection des données']
#    -> protection des données ET bac+5
#    -> protection des données ET bac+4
#    -> protection des données ET bac+3
#    -> protection des données
# développement web
# ['développement web ET bac+5', 'développement web ET bac+4', 'développement web ET bac+3', 'développement web']
#    -> développement web ET bac+5
# Error: 204
#    -> développement web ET bac+4
#    -> développement web ET bac+3
#    -> développement web
# UX
# ['UX ET bac+5', 'UX ET bac+4', 'UX ET bac+3', 'UX']
#    -> UX ET bac+5
#    -> UX ET bac+4
#    -> UX ET bac+3
#    -> UX
# ingénierie des systèmes
# ['ingénierie des systèmes ET bac+5', 'ingénierie des systèmes ET bac+4', 'ingénierie des systèmes ET bac+3', 'ingénierie des systèmes']
#    -> ingénierie des systèmes ET bac+5
#    -> ingénierie des systèmes ET bac+4
# Error: 204
#    -> ingénierie des systèmes ET bac+3
# Error: 204
#    -> ingénierie des systèmes
# ingénierie 3d, robotique, mécatronique
# ['ingénierie 3d, robotique, mécatronique ET bac+5', 'ingénierie 3d, robotique, mécatronique ET bac+4', 'ingénierie 3d, robotique, mécatronique ET bac+3', 'ingénierie 3d ET bac+5', 'robotique ET bac+5', 'mécatronique ET bac+5', 'ingénierie 3d ET bac+4', 'robotique ET bac+4', 'mécatronique ET bac+4', 'ingénierie 3d ET bac+3', 'robotique ET bac+3', 'mécatronique ET bac+3', 'ingénierie 3d, robotique, mécatronique', 'ingénierie 3d', 'robotique', 'mécatronique']
#    -> ingénierie 3d, robotique, mécatronique ET bac+5
# Error: 204
#    -> ingénierie 3d, robotique, mécatronique ET bac+4
# Error: 204
#    -> ingénierie 3d, robotique, mécatronique ET bac+3
# Error: 204
#    -> ingénierie 3d ET bac+5
#    -> robotique ET bac+5
#    -> mécatronique ET bac+5
#    -> ingénierie 3d ET bac+4
# Error: 204
#    -> robotique ET bac+4
#    -> mécatronique ET bac+4
#    -> ingénierie 3d ET bac+3
# Error: 204
#    -> robotique ET bac+3
#    -> mécatronique ET bac+3
#    -> ingénierie 3d, robotique, mécatronique
# Error: 204
#    -> ingénierie 3d
#    -> robotique
# intelligence artificielle
# ['intelligence artificielle ET bac+5', 'intelligence artificielle ET bac+4', 'intelligence artificielle ET bac+3', 'intelligence artificielle']
#    -> intelligence artificielle ET bac+5
#    -> intelligence artificielle ET bac+4
# Error: 204
#    -> intelligence artificielle ET bac+3
# Error: 204
#    -> intelligence artificielle
# stratégie web, web marketing
# ['stratégie web, web marketing ET bac+5', 'stratégie web, web marketing ET bac+4', 'stratégie web, web marketing ET bac+3', 'stratégie web ET bac+5', 'web marketing ET bac+5', 'stratégie web ET bac+4', 'web marketing ET bac+4', 'stratégie web ET bac+3', 'web marketing ET bac+3', 'stratégie web, web marketing', 'stratégie web', 'web marketing']
#    -> stratégie web, web marketing ET bac+5
# Error: 204
#    -> stratégie web, web marketing ET bac+4
# Error: 204
#    -> stratégie web, web marketing ET bac+3
# Error: 204
#    -> stratégie web ET bac+5
# Error: 204
#    -> web marketing ET bac+5
#    -> stratégie web ET bac+4
# Error: 204
#    -> web marketing ET bac+4
#    -> stratégie web ET bac+3
# Error: 204
#    -> web marketing ET bac+3
#    -> stratégie web, web marketing
#    -> stratégie web
#    -> web marketing
# management des systèmes d'information
# ["management des systèmes d'information ET bac+5", "management des systèmes d'information ET bac+4", "management des systèmes d'information ET bac+3", "management des systèmes d'information"]
#    -> management des systèmes d'information ET bac+5
#    -> management des systèmes d'information ET bac+4
#    -> management des systèmes d'information ET bac+3
#    -> management des systèmes d'information
# télécoms, réseaux
# ['télécoms, réseaux ET bac+5', 'télécoms, réseaux ET bac+4', 'télécoms, réseaux ET bac+3', 'télécoms ET bac+5', 'réseaux ET bac+5', 'télécoms ET bac+4', 'réseaux ET bac+4', 'télécoms ET bac+3', 'réseaux ET bac+3', 'télécoms, réseaux', 'télécoms', 'réseaux']
#    -> télécoms, réseaux ET bac+5
#    -> télécoms, réseaux ET bac+4
#    -> télécoms, réseaux ET bac+3
#    -> télécoms ET bac+5
#    -> réseaux ET bac+5
#    -> télécoms ET bac+4
#    -> réseaux ET bac+4
# risques industriels
# ['risques industriels ET bac+5', 'risques industriels ET bac+4', 'risques industriels ET bac+3', 'risques industriels']
#    -> risques industriels ET bac+5
#    -> risques industriels ET bac+4
#    -> risques industriels ET bac+3
#    -> risques industriels
# intelligence economique
# ['intelligence economique ET bac+5', 'intelligence economique ET bac+4', 'intelligence economique ET bac+3', 'intelligence economique']
#    -> intelligence economique ET bac+5
# Error: 204
#    -> intelligence economique ET bac+4
# Error: 204
#    -> intelligence economique ET bac+3
# Error: 204
#    -> intelligence economique
# sécurité, défense
# ['sécurité, défense ET bac+5', 'sécurité, défense ET bac+4', 'sécurité, défense ET bac+3', 'sécurité ET bac+5', 'défense ET bac+5', 'sécurité ET bac+4', 'défense ET bac+4', 'sécurité ET bac+3', 'défense ET bac+3', 'sécurité, défense', 'sécurité', 'défense']
#    -> sécurité, défense ET bac+5
#    -> sécurité, défense ET bac+4
#    -> sécurité, défense ET bac+3
#    -> sécurité ET bac+5
# stratégie
# ['stratégie ET bac+5', 'stratégie ET bac+4', 'stratégie ET bac+3', 'stratégie']
#    -> stratégie ET bac+5
#    -> stratégie ET bac+4
#    -> stratégie ET bac+3
#    -> stratégie
