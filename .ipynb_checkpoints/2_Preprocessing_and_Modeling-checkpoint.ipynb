# %% [markdown]
# # 2. Data preprocessing & Modeling

# %% [markdown]
# ### Imports

# %%
import re
import glob
import json
import pandas as pd
import numpy as np
# import tensorflow as tf
import torch
import evaluate
from datetime import datetime
from tqdm.auto import tqdm
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TFAutoModelForSequenceClassification,
    TrainingArguments,
    Trainer,
    pipeline
)
from datasets import Dataset
from sklearn.model_selection import train_test_split

tqdm.pandas()
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ### Load data

# %%
SEED = 42
MAX_LEN = None

paths = glob.glob('./pole_emploi/*.json')
results = []

for path in paths:
    with open(path, 'r', encoding='utf-8') as f:
        results += json.load(f)

df = pd.json_normalize(results)

if MAX_LEN:
    df = df.sample(MAX_LEN, random_state=SEED)

print(df.shape)
df.head(3)
# Out:
# (82734, 60)
#         id                             intitule  \
# 0  142ZHCP  Technicien / Technicienne QSE (H/F)
# 1  142ZHCK            Assistant pre-paye  (H/F)
# 2  142ZHCJ               Cuisinier / Cuisinière
#
#                                          description  \
# 0  PAPIERS A PAVIOT, société familiale fabriquant...
# 1  Vous souhaitez rejoindre une entreprise famili...
# 2  Notre établissement recherche 2 Cuisinier(e)s ...
#
#                dateCreation         dateActualisation romeCode  \
# 0  2022-10-24T15:22:24.000Z  2022-10-24T15:22:25.000Z    H1502
# 1  2022-10-24T15:22:19.000Z  2022-10-25T08:28:25.000Z    M1501
# 2  2022-10-24T15:22:18.000Z  2022-10-25T11:37:17.000Z    G1602
#
#                                      romeLibelle  \
# 0  Management et ingénierie qualité industrielle
# 1              Assistanat en ressources humaines
# 2                           Personnel de cuisine
#
#                                   appellationlibelle typeContrat  \
# 0         Adjoint(e) au responsable QSE en industrie         CDI
# 1  Assistant / Assistante de gestion en ressource...         CDI
# 2                             Cuisinier / Cuisinière         CDI
#
#              typeContratLibelle    natureContrat experienceExige  \
# 0  Contrat à durée indéterminée  Contrat travail               D
# 1  Contrat à durée indéterminée  Contrat travail               E
# 2  Contrat à durée indéterminée  Contrat travail               E
#
#   experienceLibelle                                        competences  \
# 0  Débutant accepté  [{'code': '114647', 'libelle': 'Analyser les n...
# 1            6 mois  [{'code': '100343', 'libelle': 'Législation so...
# 2              1 an  [{'code': '104207', 'libelle': 'Préparer les v...
#
#     dureeTravailLibelle dureeTravailLibelleConverti  alternance  nombrePostes  \
# 0  37H Horaires normaux                 Temps plein       False             1
# 1  39H Horaires normaux                 Temps plein       False             1
# 2  39H Horaires normaux                 Temps plein       False             1
#
#   accessibleTH qualificationCode qualificationLibelle secteurActivite  \
# 0        False                 8    Agent de maîtrise              17
# 1        False                 6     Employé qualifié              49
# 2        False                 6     Employé qualifié              56
#
#                               secteurActiviteLibelle  \
# 0  Fabrication d'autres articles en papier ou en ...
# 1           Transports routiers de fret interurbains
# 2                        Restauration traditionnelle
#
#                             qualitesProfessionnelles offresManqueCandidats  \
# 0  [{'libelle': 'Sens de la communication', 'desc...                 False
# 1  [{'libelle': 'Réactivité', 'description': 'Cap...                 False
# 2                                                NaN                 False
#
#   lieuTravail.libelle  lieuTravail.latitude  lieuTravail.longitude  \
# 0         69 - CORBAS             45.666017               4.909309
# 1  42 - LA FOUILLOUSE             45.501106               4.315670
# 2       64 - BIARRITZ             43.471440              -1.555081
#
#   lieuTravail.codePostal lieuTravail.commune    entreprise.nom  \
# 0                  69960               69273  PAPIERS A PAVIOT
# 1                  42480               42097               LTR
# 2                  64200               64122           OCTOPUS
#
#                               entreprise.description  \
# 0  PME familiale bien implantée sur le marché fab...
# 1  Vous souhaitez rejoindre une entreprise famili...
# 2                                                NaN
#
#                                       entreprise.url  \
# 0  http://www.papiers-paviot.fr/entreprise-ressou...
# 1  http://www.transport-ltr.com/carrieres/opportu...
# 2                                                NaN
#
#    entreprise.entrepriseAdaptee  \
# 0                         False
# 1                         False
# 2                         False
#
#                                      salaire.libelle  \
# 0  Mensuel de 2100,00 Euros à 2500,00 Euros sur 1...
# 1  Mensuel de 1950,00 Euros à 2600,00 Euros sur 1...
# 2                                                NaN
#
#                           contact.nom  \
# 0  PAPIERS A PAVIOT - Mme Maud DIEMER
# 1       LTR - Mme RECRUTEMENT SERVICE
# 2                Pôle Emploi BIARRITZ
#
#                                 contact.coordonnees1  \
# 0  Pour postuler, utiliser le lien suivant : http...
# 1  Pour postuler, utiliser le lien suivant : http...
# 2                            8 ter RUE BORDE D ANDRE
#
#                                     contact.courriel origineOffre.origine  \
# 0  Pour postuler, utiliser le lien suivant : http...                    1
# 1  Pour postuler, utiliser le lien suivant : http...                    1
# 2                                                NaN                    1
#
#                              origineOffre.urlOrigine  \
# 0  https://candidat.pole-emploi.fr/offres/recherc...
# 1  https://candidat.pole-emploi.fr/offres/recherc...
# 2  https://candidat.pole-emploi.fr/offres/recherc...
#
#                                      entreprise.logo    salaire.commentaire  \
# 0                                                NaN                    NaN
# 1  https://entreprise.pole-emploi.fr/static/img/l...                    NaN
# 2                                                NaN  1900 à 2000 euros net
#
#   salaire.complement1 contact.coordonnees2  \
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2               Autre       64200 BIARRITZ
#
#                                 contact.coordonnees3  \
# 0                                                NaN
# 1                                                NaN
# 2  Pour postuler, utiliser le lien suivant : http...
#
#                                      agence.courriel langues permis  \
# 0                                                NaN     NaN    NaN
# 1                                                NaN     NaN    NaN
# 2  Pour postuler, utiliser le lien suivant : http...     NaN    NaN
#
#   deplacementCode deplacementLibelle formations complementExercice  \
# 0             NaN                NaN        NaN                NaN
# 1             NaN                NaN        NaN                NaN
# 2             NaN                NaN        NaN                NaN
#
#   salaire.complement2 experienceCommentaire contact.urlPostulation  \
# 0                 NaN                   NaN                    NaN
# 1                 NaN                   NaN                    NaN
# 2                 NaN                   NaN                    NaN
#
#   agence.telephone contact.telephone contact.commentaire conditionExercice  \
# 0              NaN               NaN                 NaN               NaN
# 1              NaN               NaN                 NaN               NaN
# 2              NaN               NaN                 NaN               NaN
#
#   origineOffre.partenaires
# 0                      NaN
# 1                      NaN
# 2                      NaN

# %% [markdown]
# ### Data preprocessing
# Clean nulls, format date attributes, drop duplicated jobs.

# %%
dfp = df.copy()

dfp.dropna(subset=['id', 'dateCreation',
                   'dateActualisation', 'description', 'intitule'],
           inplace=True)

for col in ['dateCreation', 'dateActualisation']:
    dfp[col] = pd.to_datetime(dfp[col], format='%Y-%m-%dT%H:%M:%S.%fZ')
    
dfp.sort_values(['dateActualisation'], ascending=False, inplace=True)

dfp.drop_duplicates(subset=['id'], keep='first', inplace=True)
dfp.drop_duplicates(subset=['description'], keep='first', inplace=True)
dfp.drop_duplicates(subset=['intitule'], keep='first', inplace=True)

dfp = dfp[['id', 'dateActualisation', 'romeCode', 'intitule', 'description']] \
         .reset_index(drop=True) \
         .copy()

print(dfp.shape)
dfp.head(3)
# Out:
# (33778, 5)
#         id   dateActualisation romeCode  \
# 0  142NPSB 2022-10-27 08:06:02    G1603
# 1  142NTLG 2022-10-27 08:00:35    G1605
# 2  142NPQB 2022-10-27 08:00:11    H2913
#
#                                             intitule  \
# 0  Employé de laboratoire de préparation de pizza...
# 1               Plongeur / Plongeuse en restauration
# 2          soudeur métal sur matériel agricole (H/F)
#
#                                          description
# 0  Nous recherchons un employé polyvalent (H/F) p...
# 1  Vous avez une capacité d'adaptation et un rela...
# 2  Soudure sur des ensembles en acier non alliés ...

# %% [markdown]
# ### Data augmentation (+50% incorrect pairs)
# Mix correct data with incorrect job-description pairs for future classifier training.

# %%
dfa = dfp.copy()

dfa_left = dfa.copy()
dfa_right = dfa.copy()

agg = dfa.groupby(['romeCode', 'intitule']).last().reset_index()[['romeCode', 'intitule']]
rome_job_mapper = agg.set_index('romeCode').stack().groupby('romeCode').apply(list).to_dict()
romes = list(rome_job_mapper.keys())

def find_fake_job(row):
    choices = [x for x in romes if x != row['romeCode']]
    choice = np.random.choice(choices)
    fake_jobs = rome_job_mapper[choice]
    return np.random.choice(fake_jobs)

dfa_right['intitule'] = dfa_right.progress_apply(find_fake_job, axis=1)

dfa_left['label'] = 0
dfa_right['label'] = 2

dfa = pd.concat([dfa_left, dfa_right], ignore_index=True)
print(dfa.shape)
dfa.groupby(['label']).size()
# Out:
#   0%|          | 0/33778 [00:00<?, ?it/s]
# (67556, 6)
# label
# 0    33778
# 2    33778
# dtype: int64

# %% [markdown]
# ### Dataset generation

# %%
model_name = "valhalla/distilbart-mnli-12-1"
model_name = "BaptisteDoyen/camembert-base-xnli"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name).to('cuda')

# %%
SEED = 42

dff = dfa.copy()

dff['intitule'] = dff['intitule'].map(lambda x: f'Ce texte est à propos de {x}')
dff['description'] = dff['description'].map(lambda x: x[:925])

ds = Dataset.from_dict(dff[['description', 'intitule', 'label']].to_dict('list'))
ds = ds.shuffle(seed=SEED)
ds = ds.train_test_split(test_size=0.33)

def tokenize_sequence_pairs(row):
    return tokenizer(row['description'],
                     row['intitule'],
                     padding='max_length',
                     truncation=True)

ds = ds.map(tokenize_sequence_pairs)
ds = ds.remove_columns(["description", 'intitule'])

ds
# Out:
#   0%|          | 0/45262 [00:00<?, ?ex/s]
#   0%|          | 0/22294 [00:00<?, ?ex/s]
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 45262
#     })
#     test: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 22294
#     })
# })

# %% [markdown]
# ### Model training

# %%
metric = evaluate.load('accuracy')

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return metric.compute(predictions=predictions, references=labels)

training_args = TrainingArguments(
    "Camembert-Jobs",
    report_to="none",
    num_train_epochs=3,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=100,
    # gradient_accumulation_steps=4,
    # gradient_checkpointing=True
)

trainer = Trainer(
    model,
    training_args,
    train_dataset=ds["train"],
    eval_dataset=ds["test"],
    compute_metrics=compute_metrics
)

# %%
trainer.train("./Camembert-Jobs/checkpoint-2500/")
# Out:
# Loading model from ./Camembert-Jobs/checkpoint-2500/.
# ***** Running training *****
#   Num examples = 45262
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 16974
#   Continuing training from checkpoint, will skip to saved global_step
#   Continuing training from epoch 0
#   Continuing training from global step 2500
#   Will skip the first 0 epochs then the first 2500 batches in the first epoch. If this takes a lot of time, you can add the `--ignore_data_skip` flag to your launch command, but you will resume the training on data already seen by your model.
#   0%|          | 0/2500 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='16974' max='16974' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [16974/16974 7:24:52, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2600</td>
#       <td>0.167000</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.220600</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.236800</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.211700</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.211400</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.177400</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.211800</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.155600</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.188900</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.189700</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.175400</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.174900</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.236400</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.202400</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.200100</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.183700</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.182000</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.173900</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.158200</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.178800</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.225300</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.186200</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.216400</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.193600</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.231800</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.155800</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.199700</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.147600</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.199500</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.172500</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.169400</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.141500</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.163000</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.146700</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.114200</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>0.123900</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>0.160600</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>0.091600</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.149600</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.184900</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>0.136500</td>
#     </tr>
#     <tr>
#       <td>6700</td>
#       <td>0.099600</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>0.126400</td>
#     </tr>
#     <tr>
#       <td>6900</td>
#       <td>0.150900</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.125400</td>
#     </tr>
#     <tr>
#       <td>7100</td>
#       <td>0.159700</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.117300</td>
#     </tr>
#     <tr>
#       <td>7300</td>
#       <td>0.145400</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>0.136400</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.145400</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>0.178200</td>
#     </tr>
#     <tr>
#       <td>7700</td>
#       <td>0.106300</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>0.105300</td>
#     </tr>
#     <tr>
#       <td>7900</td>
#       <td>0.134000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.115900</td>
#     </tr>
#     <tr>
#       <td>8100</td>
#       <td>0.111800</td>
#     </tr>
#     <tr>
#       <td>8200</td>
#       <td>0.103300</td>
#     </tr>
#     <tr>
#       <td>8300</td>
#       <td>0.130700</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.140800</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.125700</td>
#     </tr>
#     <tr>
#       <td>8600</td>
#       <td>0.116900</td>
#     </tr>
#     <tr>
#       <td>8700</td>
#       <td>0.109500</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>0.109200</td>
#     </tr>
#     <tr>
#       <td>8900</td>
#       <td>0.114800</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.129400</td>
#     </tr>
#     <tr>
#       <td>9100</td>
#       <td>0.112000</td>
#     </tr>
#     <tr>
#       <td>9200</td>
#       <td>0.141200</td>
#     </tr>
#     <tr>
#       <td>9300</td>
#       <td>0.124400</td>
#     </tr>
#     <tr>
#       <td>9400</td>
#       <td>0.123500</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.112000</td>
#     </tr>
#     <tr>
#       <td>9600</td>
#       <td>0.133100</td>
#     </tr>
#     <tr>
#       <td>9700</td>
#       <td>0.130300</td>
#     </tr>
#     <tr>
#       <td>9800</td>
#       <td>0.122500</td>
#     </tr>
#     <tr>
#       <td>9900</td>
#       <td>0.100900</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.116800</td>
#     </tr>
#     <tr>
#       <td>10100</td>
#       <td>0.134800</td>
#     </tr>
#     <tr>
#       <td>10200</td>
#       <td>0.119800</td>
#     </tr>
#     <tr>
#       <td>10300</td>
#       <td>0.114500</td>
#     </tr>
#     <tr>
#       <td>10400</td>
#       <td>0.081000</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.129900</td>
#     </tr>
#     <tr>
#       <td>10600</td>
#       <td>0.121800</td>
#     </tr>
#     <tr>
#       <td>10700</td>
#       <td>0.121000</td>
#     </tr>
#     <tr>
#       <td>10800</td>
#       <td>0.111700</td>
#     </tr>
#     <tr>
#       <td>10900</td>
#       <td>0.110700</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.089000</td>
#     </tr>
#     <tr>
#       <td>11100</td>
#       <td>0.148600</td>
#     </tr>
#     <tr>
#       <td>11200</td>
#       <td>0.078000</td>
#     </tr>
#     <tr>
#       <td>11300</td>
#       <td>0.081900</td>
#     </tr>
#     <tr>
#       <td>11400</td>
#       <td>0.027100</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.061900</td>
#     </tr>
#     <tr>
#       <td>11600</td>
#       <td>0.051100</td>
#     </tr>
#     <tr>
#       <td>11700</td>
#       <td>0.081800</td>
#     </tr>
#     <tr>
#       <td>11800</td>
#       <td>0.032400</td>
#     </tr>
#     <tr>
#       <td>11900</td>
#       <td>0.037300</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.039200</td>
#     </tr>
#     <tr>
#       <td>12100</td>
#       <td>0.055200</td>
#     </tr>
#     <tr>
#       <td>12200</td>
#       <td>0.062100</td>
#     </tr>
#     <tr>
#       <td>12300</td>
#       <td>0.035400</td>
#     </tr>
#     <tr>
#       <td>12400</td>
#       <td>0.072100</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.035900</td>
#     </tr>
#     <tr>
#       <td>12600</td>
#       <td>0.050200</td>
#     </tr>
#     <tr>
#       <td>12700</td>
#       <td>0.091900</td>
#     </tr>
#     <tr>
#       <td>12800</td>
#       <td>0.042800</td>
#     </tr>
#     <tr>
#       <td>12900</td>
#       <td>0.059300</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.068500</td>
#     </tr>
#     <tr>
#       <td>13100</td>
#       <td>0.046100</td>
#     </tr>
#     <tr>
#       <td>13200</td>
#       <td>0.060500</td>
#     </tr>
#     <tr>
#       <td>13300</td>
#       <td>0.080800</td>
#     </tr>
#     <tr>
#       <td>13400</td>
#       <td>0.055900</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.088000</td>
#     </tr>
#     <tr>
#       <td>13600</td>
#       <td>0.036300</td>
#     </tr>
#     <tr>
#       <td>13700</td>
#       <td>0.042800</td>
#     </tr>
#     <tr>
#       <td>13800</td>
#       <td>0.089300</td>
#     </tr>
#     <tr>
#       <td>13900</td>
#       <td>0.022600</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.042400</td>
#     </tr>
#     <tr>
#       <td>14100</td>
#       <td>0.066700</td>
#     </tr>
#     <tr>
#       <td>14200</td>
#       <td>0.071600</td>
#     </tr>
#     <tr>
#       <td>14300</td>
#       <td>0.056000</td>
#     </tr>
#     <tr>
#       <td>14400</td>
#       <td>0.055600</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.036600</td>
#     </tr>
#     <tr>
#       <td>14600</td>
#       <td>0.075400</t
# Saving model checkpoint to Camembert-Jobs\checkpoint-3000
# Configuration saved in Camembert-Jobs\checkpoint-3000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-3000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-3500
# Configuration saved in Camembert-Jobs\checkpoint-3500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-3500\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-4000
# Configuration saved in Camembert-Jobs\checkpoint-4000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-4000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-4500
# Configuration saved in Camembert-Jobs\checkpoint-4500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-4500\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-5000
# Configuration saved in Camembert-Jobs\checkpoint-5000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-5000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-5500
# Configuration saved in Camembert-Jobs\checkpoint-5500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-5500\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-6000
# Configuration saved in Camembert-Jobs\checkpoint-6000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-6000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-6500
# Configuration saved in Camembert-Jobs\checkpoint-6500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-6500\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-7000
# Configuration saved in Camembert-Jobs\checkpoint-7000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-7000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-7500
# Configuration saved in Camembert-Jobs\checkpoint-7500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-7500\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-8000
# Configuration saved in Camembert-Jobs\checkpoint-8000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-8000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-8500
# Configuration saved in Camembert-Jobs\checkpoint-8500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-8500\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-9000
# Configuration saved in Camembert-Jobs\checkpoint-9000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-9000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-9500
# Configuration saved in Camembert-Jobs\checkpoint-9500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-9500\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-10000
# Configuration saved in Camembert-Jobs\checkpoint-10000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-10000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-10500
# Configuration saved in Camembert-Jobs\checkpoint-10500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-10500\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-11000
# Configuration saved in Camembert-Jobs\checkpoint-11000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-11000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-11500
# Configuration saved in Camembert-Jobs\checkpoint-11500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-11500\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-12000
# Configuration saved in Camembert-Jobs\checkpoint-12000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-12000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-12500
# Configuration saved in Camembert-Jobs\checkpoint-12500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-12500\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-13000
# Configuration saved in Camembert-Jobs\checkpoint-13000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-13000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-13500
# Configuration saved in Camembert-Jobs\checkpoint-13500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-13500\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-14000
# Configuration saved in Camembert-Jobs\checkpoint-14000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-14000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-14500
# Configuration saved in Camembert-Jobs\checkpoint-14500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-14500\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-15000
# Configuration saved in Camembert-Jobs\checkpoint-15000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-15000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-15500
# Configuration saved in Camembert-Jobs\checkpoint-15500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-15500\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-16000
# Configuration saved in Camembert-Jobs\checkpoint-16000\config.json
# Model weights saved in Camembert-Jobs\checkpoint-16000\pytorch_model.bin
# Saving model checkpoint to Camembert-Jobs\checkpoint-16500
# Configuration saved in Camembert-Jobs\checkpoint-16500\config.json
# Model weights saved in Camembert-Jobs\checkpoint-16500\pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=16974, training_loss=0.09446865017512135, metrics={'train_runtime': 26708.8874, 'train_samples_per_second': 5.084, 'train_steps_per_second': 0.636, 'total_flos': 3.600286140139315e+16, 'train_loss': 0.09446865017512135, 'epoch': 3.0})

# %% [markdown]
# ### Model evaluation

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 22294
#   Batch size = 8
#     <div>
#
#       <progress value='2787' max='2787' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2787/2787 12:27]
#     </div>
# {'eval_loss': 0.18959441781044006,
#  'eval_accuracy': 0.966179241051404,
#  'eval_runtime': 748.0063,
#  'eval_samples_per_second': 29.805,
#  'eval_steps_per_second': 3.726,
#  'epoch': 3.0}

# %%
trainer.save_model('./Camembert-Jobs/final')
# Out:
# Saving model checkpoint to ./Camembert-Jobs/final
# Configuration saved in ./Camembert-Jobs/final\config.json
# Model weights saved in ./Camembert-Jobs/final\pytorch_model.bin

# %%
best_model = AutoModelForSequenceClassification.from_pretrained('./Camembert-Jobs/final/')
# Out:
# loading configuration file ./Camembert-Jobs/final/config.json
# Model config CamembertConfig {
#   "_name_or_path": "./Camembert-Jobs/final/",
#   "architectures": [
#     "CamembertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 5,
#   "classifier_dropout": null,
#   "eos_token_id": 6,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "entailment",
#     "1": "neutral",
#     "2": "contradiction"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "contradiction": 2,
#     "entailment": 0,
#     "neutral": 1
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "camembert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 32005
# }
#
# loading weights file ./Camembert-Jobs/final/pytorch_model.bin
# All model checkpoint weights were used when initializing CamembertForSequenceClassification.
#
# All the weights of CamembertForSequenceClassification were initialized from the model checkpoint at ./Camembert-Jobs/final/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use CamembertForSequenceClassification for predictions without further training.

# %% [markdown]
# ### Using the model through a zero shot classification pipeline

# %%
# job = "Vous aurez pour: mission d'intervenir au sein du domicile des bénéficiaires pour les accompagner dans les actes essentiels de leur vie quotidienne et leur offrir un soutien social leur permettant un maintien à domicile. \n\nMissions :\n-\tEntretenir le cadre de vie du bénéficiaire \n-\tFaire les courses, préparer et aider à la prise de repas\n-\tAccompagner dans les activités de loisirs et de la vie sociale.\n\nL'humain étant au cœur de nos préoccupations, nous vous garantissons les avantages suivants :  \n-\tUn planning co-construit et adapté \n-\tUne sectorisation près de chez vous \n-\tDes compléments de rémunération : prise en charge +50% titre de transport, +25% majoration dimanches et jours fériés.\n-\tUne mutuelle d'entreprise \n-\tUn dispositif de pourcentage patronal à l'action logement  \n-\tUn parcours d'intégration personnalisé"
zsc = pipeline('zero-shot-classification', model=best_model, tokenizer=tokenizer)
weighted_scores = zsc(
    job,
    candidate_labels=['ingénieur cybersécurité', 'data scientist', 'développeur web', 'femme de ménage', 'big data', 'cybersécurité', 'intelligence des données'],
    hypothesis_template='Ce texte est à propose de {}')
scores = zsc(
    job,
    candidate_labels=['ingénieur cybersécurité', 'data scientist', 'développeur web', 'femme de ménage', 'big data', 'cybersécurité', 'intelligence des données'],
    hypothesis_template='Ce texte est à propose de {}',
    multi_label=True)

del weighted_scores['sequence']
del scores['sequence']

print('Weighted scores')
for k, v in zip(weighted_scores['labels'], weighted_scores['scores']):
    print(f'   - {k}: {v:.2f}')

print('\nIndividual scores')
for k, v in zip(scores['labels'], scores['scores']):
    print(f'   - {k}: {v:.2f}')
# Out:
# Weighted scores
#    - cybersécurité: 0.31
#    - ingénieur cybersécurité: 0.30
#    - big data: 0.23
#    - data scientist: 0.16
#    - intelligence des données: 0.00
#    - développeur web: 0.00
#    - femme de ménage: 0.00
#
# Individual scores
#    - ingénieur cybersécurité: 1.00
#    - cybersécurité: 1.00
#    - big data: 1.00
#    - data scientist: 0.99
#    - intelligence des données: 0.01
#    - développeur web: 0.00
#    - femme de ménage: 0.00
